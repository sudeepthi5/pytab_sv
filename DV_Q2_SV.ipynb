# %% [markdown]
# #### QUESTION2
#
# Using the COVID data, a line graph showing the moving average and the number of daily cases for Pasco was created.

# %% [markdown]
# #### importing the file

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r'C:\Users\HP\Downloads\Combined-1.xlsx', sheet_name='Pasco', names = ['Date', 'Daily Number', 'Moving Average'])

df.head()
# Out:
#         Date  Daily Number  Moving Average
# 0 2020-03-01             2             2.0
# 1 2020-03-02             1             1.5
# 2 2020-03-07             2             1.7
# 3 2020-03-08             3             2.0
# 4 2020-03-09             5             2.6

# %%
df.plot('Date', ['Daily Number', 'Moving Average'], xticks=[])
# Out:
# <AxesSubplot:xlabel='Date'>
